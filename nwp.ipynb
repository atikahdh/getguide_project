arai \n Desa Tradisional Bena Ngada \n Manta Point Manggarai \n Pulau Rinca Manggarai \n Danau Sanonggoang Manggorang \n Kampung Adat Praiyawang Sumba \n Kampung Adat Ratenggaro Sumba \n Rumah Budaya Sumba \n Benteng None Timor Tengah \n Benteng Makes (7 Lapis) Belu \n Pulau Padar Manggarai \n Desa Wae Rebo Manggarai \n Air Terjun Lapopu Sumba"

# Split each destination and lower all the letters
corpus = destination.lower().split(" \n ")

print(corpus[:10])

# %% [markdown]
# Generate each word index dictionary and compute the total words

# %%
# Initialize Tokenizer class
tokenizer = Tokenizer()

# Generate the word index dictionary
tokenizer.fit_on_texts(corpus)

# Define the total words. Add 1 for the index `0` as the padding token.
total_words = len(tokenizer.word_index) + 1

print(f'word index dictionary: {tokenizer.word_index}')
print(f'total words: {total_words}')

# %% [markdown]
# ## Preprocessing the Dataset
#
# Here we will generate the training sequences which the result would be inputs as padded sequences and the labels will be labelled as one-hot encoded arrays.

# %%
# Initialize the sequences list
input_sequences = []

# Loop over every line
for line in corpus:

	# Tokenize the current line
	token_list = tokenizer.texts_to_sequences([line])[0]

	# Loop over the line several times to generate the subphrases
	for i in range(1, len(token_list)):
		
		# Generate the subphrase
		n_gram_sequence = token_list[:i+1]

		# Append the subphrase to the sequences list
		input_sequences.append(n_gram_sequence)

# Get the length of the longest line
max_sequence_len = max([len(x) for x in input_sequences])

# Pad all sequences
input_sequences = np.array(pad_sequences(input_sequences, maxlen = max_sequence_len, padding='pre'))

# Create inputs and label by splitting the last token in the subphrases
xs, labels = input_sequences[:,:-1],input_sequences[:,-1]

# Convert the label into one-hot arrays
ys = tf.keras.utils.to_categorical(labels, num_classes = total_words)

# %% [markdown]
# ## Build the Model

# %%
model = Sequential([
          Embedding(total_words, 64, input_length = max_sequence_len-1),
          LSTM(40),
          Dense(total_words, activation = 'softmax')])

model.compile(loss='categorical_crossentropy',
              optimizer = tf.keras.optimizers.Adam(learning_rate = 0.003),
              metrics = ['accuracy'])

# %% [markdown]
# ## Show the Model Summary

# %%
model.summary()

# %% [markdown]
# ## Plot the Model

# %%
keras.utils.plot_model(model, to_file='plot.png', show_layer_names=True)

# %% [markdown]
# ## Train the Model

# %%
history = model.fit(xs, ys, epochs = 200)
# validation_split=0.02

# %% [markdown]
# ## Visual the Result

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.show()

# Visualize the accuracy
plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %% [markdown]
# ## Save the Model

# %%
saved_model_path = "nwp.h5"

model.save(saved_model_path)

# %% [markdown]
# To JSON

# %%
# !tensorflowjs_converter --input_format=keras {saved_model_path} ./

# %% [markdown]
# ## Make Prediction

# %%
vocab_array = np.array(list(tokenizer.word_index.keys()))

def make_prediction(text, n_words):
    for i in range(n_words):
        text_tokenize = tokenizer.texts_to_sequences([text])
        text_padded = tf.keras.preprocessing.sequence.pad_sequences(text_tokenize, maxlen = max_sequence_len-1)
        prediction = np.squeeze(np.argmax(model.predict(text_padded), axis = -1))
        prediction = str(vocab_array[prediction - 1])
        text += " " + prediction.capitalize()
    return text

# %%
text_new = input("Enter your destination: ")

# %%
make_prediction(text_new, 2)
